# %% [markdown]
# ### Imports and Benchmark Config

# %%
from spatialreasoning import BenchmarkConfig, run_full_benchmark, analyze_results

config = BenchmarkConfig(
        #models=['gemma4:e2b'],
        models=['gemma3:latest', 'gemma4:e2b', 'gemma4:latest', 'gemma4:26b', 'qwen3:latest', 'qwen3.6:27b', 'mistral:7b'],
        model_aliases={
            'gemma3:latest': 'gemma3:4b',
            'gemma4:latest': 'gemma4:e4b',
            'qwen3:latest':  'qwen3:8b',
            },
        repeats=1,
        task_directory="../../src/spatialreasoning/tasks_complex",
        output_directory="./results",
        filter_tags=[],  # empty = run all tasks; e.g. ['2d'] to filter by tag
        think=False
    )

# %% [markdown]
# ### Run Benchmark

# %%
run_full_benchmark(config)
# Out:
# [VALIDATION] All checks passed.
# Running benchmark for model: gemma3:4b, Repeat: 1/1
# Running benchmark for model: gemma4:e2b, Repeat: 1/1
# Running benchmark for model: gemma4:e4b, Repeat: 1/1
# Running benchmark for model: gemma4:26b, Repeat: 1/1
# Running benchmark for model: qwen3:8b, Repeat: 1/1
# Running benchmark for model: qwen3.6:27b, Repeat: 1/1
# Running benchmark for model: mistral:7b, Repeat: 1/1
# Model: gemma3:4b, Repeat: 1, Score: 2 / 150 (1.3%)
# Model: gemma4:e2b, Repeat: 1, Score: 0 / 150 (0.0%)
# Model: gemma4:e4b, Repeat: 1, Score: 0 / 150 (0.0%)
# Model: gemma4:26b, Repeat: 1, Score: 0 / 150 (0.0%)
# Model: qwen3:8b, Repeat: 1, Score: 7 / 150 (4.7%)
# Model: qwen3.6:27b, Repeat: 1, Score: 1 / 150 (0.7%)
# Model: mistral:7b, Repeat: 1, Score: 0 / 150 (0.0%)
# Saved results to ./results\gemma34b\20260424_201703.yml
# Saved results to ./results\gemma4e2b\20260424_201703.yml
# Saved results to ./results\gemma4e4b\20260424_201703.yml
# Saved results to ./results\gemma426b\20260424_201703.yml
# Saved results to ./results\qwen38b\20260424_201703.yml
# Saved results to ./results\qwen3.627b\20260424_201703.yml
# Saved results to ./results\mistral7b\20260424_201703.yml
# Model: gemma3:4b
#   Overall Score: 2 / 150  (1.3%)
#   Tag [3d]: 2 / 150
#   Tag [rotation]: 2 / 150
#   Tag [die]: 2 / 150
#   Tag [multi_transformation]: 2 / 150
#   Tag [3d_rotations_multi_die]: 2 / 150
#
# Model: gemma4:e2b
#   Overall Score: 0 / 150  (0.0%)
#   Tag [3d]: 0 / 150
#   Tag [rotation]: 0 / 150
#   Tag [die]: 0 / 150
#   Tag [multi_transformation]: 0 / 150
#   Tag [3d_rotations_multi_die]: 0 / 150
#
# Model: gemma4:e4b
#   Overall Score: 0 / 150  (0.0%)
#   Tag [3d]: 0 / 150
#   Tag [rotation]: 0 / 150
#   Tag [die]: 0 / 150
#   Tag [multi_transformation]: 0 / 150
#   Tag [3d_rotations_multi_die]: 0 / 150
#
# Model: gemma4:26b
#   Overall Score: 0 / 150  (0.0%)
#   Tag [3d]: 0 / 150
#   Tag [rotation]: 0 / 150
#   Tag [die]: 0 / 150
#   Tag [multi_transformation]: 0 / 150
#   Tag [3d_rotations_multi_die]: 0 / 150
#
# Model: qwen3:8b
#   Overall Score: 7 / 150  (4.7%)
#   Tag [3d]: 7 / 150
#   Tag [rotation]: 7 / 150
#   Tag [die]: 7 / 150
#   Tag [multi_transformation]: 7 / 150
#   Tag [3d_rotations_multi_die]: 7 / 150
#
# Model: qwen3.6:27b
#   Overall Score: 1 / 150  (0.7%)
#   Tag [3d]: 1 / 150
#   Tag [rotation]: 1 / 150
#   Tag [die]: 1 / 150
#   Tag [multi_transformation]: 1 / 150
#   Tag [3d_rotations_multi_die]: 1 / 150
#
# Model: mistral:7b
#   Overall Score: 0 / 150  (0.0%)
#   Tag [3d]: 0 / 150
#   Tag [rotation]: 0 / 150
#   Tag [die]: 0 / 150
#   Tag [multi_transformation]: 0 / 150
#   Tag [3d_rotations_multi_die]: 0 / 150

# %% [markdown]
# ### Analyze Results

# %%
# Perform Categorical Analysis (Per-Catgeory accuracy/Total Average Accuracy)
analyze_results(
    output_dir="./results",
    save_dir="./analysis/categorical_analysis",
    filter_tags=[ 
                    '3d_rotations_multi_die', 
                ],  # empty = all tags; e.g. ['2d'] to restrict
    tag_plot_title="Per-Category Accuracy by Model",
    plot_overall_accuracy=True
)

from IPython.display import Image

# Display ./analysis/categorical_analysis/model_accuracy.png
Image("./analysis/categorical_analysis/model_accuracy.png")
# Out:
# Saved analysis CSV to ./analysis/categorical_analysis\analysis.csv
# Saved model accuracy plot to ./analysis/categorical_analysis\model_accuracy.png
# Saved tag accuracy plot to ./analysis/categorical_analysis\tag_accuracy.png

# %%
# Display ./analysis/categorical_analysis/model_accuracy.png
Image("./analysis/categorical_analysis/tag_accuracy.png")

# %%
# Perform Tag-Level Analysis (Per-Tag accuracy)
analyze_results(
    output_dir="./results",
    save_dir="./analysis/tag_level_analysis",
    filter_tags=[],  # empty = all tags; e.g. ['2d'] to restrict
    tag_plot_title="Per-Tag Accuracy by Model",
    plot_overall_accuracy=False
)

# Display ./analysis/tag_level_analysis/tag_accuracy.png
Image("./analysis/tag_level_analysis/tag_accuracy.png")
# Out:
# Saved analysis CSV to ./analysis/tag_level_analysis\analysis.csv
# Saved tag accuracy plot to ./analysis/tag_level_analysis\tag_accuracy.png
